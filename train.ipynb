# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
if __name__ == '__main__':
    model = YOLO("yolov8s.yaml").load(r"C:\Users\Gesser\Documents\BRUNO\yolo custom\runs\detect\train8\weights\best.pt")  # build from YAML and transfer weights
    # Train the model
    results = model.train(data=r"C:\Users\Gesser\Documents\BRUNO\input files\yolo_bruno.yaml",
                          epochs=300,
                          imgsz=256,
                          batch=260,
                          resume=True,
                          save_period=1,
                          save=True,
                          workers=12,
                          hsv_v = 0.6,
                          shear = 0.4,
                          perspective = 0.001 )
